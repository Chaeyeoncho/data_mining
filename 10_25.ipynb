# %%
# 필요한 라이브러리 임포트
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.ticker import FuncFormatter

# %%
test = pd.read_csv('/content/bigmart_test.csv')
test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
train = pd.read_csv('/content/bigmart_train.csv')
train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print('훈련데이터 사이즈 : ', train.shape)
print('테스트데이터 사이즈 : ', test.shape)
# Out:
# 훈련데이터 사이즈 :  (8523, 12)
# 테스트데이터 사이즈 :  (5681, 11)

# %%
print('훈련데이터 타입')
print(train.dtypes)
print('테스트데이터 타입')
print(test.dtypes)
# Out:
# 훈련데이터 타입
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object
# 테스트데이터 타입
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
print('훈련 데이터 타입')
print(train.describe())
print('테스트 데이터 타입')
print(test.describe())
# Out:
# 훈련 데이터 타입
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800
# 테스트 데이터 타입
# ...

# %%
print('훈련데이터 결측치\n')
print(train.isnull().sum())
print('\n')
print('테스트데이터 결측치\n')
print(test.isnull().sum())
# Out:
# 훈련데이터 결측치
#
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64
#
#
# 테스트데이터 결측치
#
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
#일변량분석
train.hist()
plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
#박스플랏
train.boxplot()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
#다변량 분석
sns.pairplot(train)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
item_type_counts = train['Item_Type'].value_counts()

# 시각화
plt.figure(figsize=(10,6))
sns.barplot(x=item_type_counts.values, y=item_type_counts.index, palette='husl')

# 그래프 제목 및 레이블
plt.title('Item Type', fontsize=20)
plt.xlabel('Count', fontsize=12)
plt.ylabel('Item_Type', fontsize=12)

# 그래프 출력
plt.show()
# Out:
# <ipython-input-137-f5af0e9be330>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=item_type_counts.values, y=item_type_counts.index, palette='husl')
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
plt.figure(figsize=(10, 6))
ax = plt.axes()
ax.set_facecolor('lightgray')  # 배경색을 밝은 회색으로 설정
sns.boxplot(x='Item_Type', y='Item_MRP', data=train,
            boxprops={'facecolor':'white', 'edgecolor':'black'}, # boxplot color
            medianprops={'color':'black'}, # median line color
            ax=ax  # Axes 객체를 sns.boxplot에 전달
           )
plt.xlabel('Item Type')
plt.ylabel('Item MRP')
plt.xticks(rotation=45, ha='right', color='red')  # x-axis label color
plt.yticks(np.arange(0, train['Item_MRP'].max() + 100, 100))
plt.title('Item Type vs Item MRP')
ax.xaxis.grid(True, color='white')
ax.yaxis.grid(True, color='white')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
#1) 아이템 노출도에 따른 아웃렛 세일
sns.scatterplot(train, x='Item_Visibility', y='Item_Outlet_Sales', facecolor='darkblue')
sns.set_style("darkgrid")
plt.title('Item Visibility vs Item Outlet Sales', position=(0.23, 1), fontsize=10, weight='bold')
plt.xticks(ticks=[0, 0.1, 0.2, 0.3], fontsize=7)
plt.yticks(ticks=[0, 5000, 10000], fontsize=7)
plt.xlabel('Item Visibility')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# ...

# %%
#5) 아웃렛 ID에 따른 갯수
sns.countplot(train, x='Outlet_Identifier',
              order=['OUT010', 'OUT013', 'OUT017', 'OUT018', 'OUT019', 'OUT027', 'OUT035', 'OUT045', 'OUT046', 'OUT049'],
              palette="husl")
sns.set_style("darkgrid")
plt.title('Count of Outlet Identifiers', fontsize=10, weight='bold')
plt.xticks(fontsize=6)
plt.yticks(ticks=[0, 500, 1000], fontsize=7)
plt.ylabel('Outlet_Count', fontsize=8,  weight='bold')
plt.xlabel('Outlet_Identifier', fontsize=8,  weight='bold')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-140-50ef57feda2c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(train, x='Outlet_Identifier',

# %%
#아이템 종류에 따른 총판매량
plt.bar(train["Item_Type"].sort_values(), train["Item_Outlet_Sales"])
plt.tight_layout()
plt.xticks(rotation=60)
plt.title("Item Type vs Sales")
plt.xlabel("Item Type")
plt.ylabel("item Outlet sales")
plt.show()

# %%
#아울렛의 설립년도에 따른 갯수
df=train["Outlet_Establishment_Year"].value_counts().sort_index()
df.plot(kind="bar")
plt.show()

# %%
sales_by_outlet = train.groupby('Outlet_Identifier')['Item_Outlet_Sales'].sum().reset_index()

def format_y_ticks(x, _):
    return f'{int(x):,}'

plt.figure(figsize=(12, 6))

# 막대 그래프 그리기
sns.barplot(data=sales_by_outlet, x='Outlet_Identifier', y='Item_Outlet_Sales', palette='viridis')

# 그래프 제목 및 축 레이블 설정
plt.title('아울렛에 따른 총판매량')
plt.xlabel('아울렛')
plt.ylabel('총 판매량')

plt.ylim(0, sales_by_outlet['Item_Outlet_Sales'].max() * 1.1)

plt.gca().yaxis.set_major_formatter(FuncFormatter(format_y_ticks))

plt.xticks(rotation=45)

plt.show()
# Out:
# <ipython-input-143-b054aeab77bb>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_by_outlet, x='Outlet_Identifier', y='Item_Outlet_Sales', palette='viridis')
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50500 (\N{HANGUL SYLLABLE A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47131 (\N{HANGUL SYLLABLE RES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# Plotting
plt.figure(figsize=(12, 6))

# 막대 그래프 그리기
sns.barplot(data=item_counts, x='Item_Identifier', y='Count', palette='viridis')

# 제목 및 축 레이블 설정 (font_prop 없이 기본 폰트 사용)
plt.title('Item Identifiers 갯수 상위 10개')
plt.xlabel('Item Identifier')
plt.ylabel('갯수')

# y축 범위 설정 (최대값의 1.1배)
plt.ylim(0, item_counts['Count'].max() * 1.1)

# x축 레이블 회전
plt.xticks(rotation=45)

# 그래프 출력
plt.show()
# Out:
# <ipython-input-144-044620f94893>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=item_counts, x='Item_Identifier', y='Count', palette='viridis')
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44079 (\N{HANGUL SYLLABLE GAES}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 테스트 테이터에 아웃렛 세일열을 만들고1을 할당
test['Item_Outlet_Sales'] = 1
test.shape
# Out:
# (5681, 12)

# %%
# 훈련과 테스트 데이터를 합침
df = pd.concat([train, test])
df.shape
# Out:
# (14204, 12)

# %%
#아이템 무게의 분실값을 중위수로 대체
df['Item_Weight'].fillna(df['Item_Weight'].median(), inplace=True)
# Out:
# <ipython-input-147-efc7a238f84a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Item_Weight'].fillna(df['Item_Weight'].median(), inplace=True)

# %%
# 노출도가 0인 데이터를 찾아서 중위수로 대체
df.loc[df['Item_Visibility'] == 0, 'Item_Visibility'] = df['Item_Visibility'].median()

# %%
df['Item_Visibility'].dtypes
# Out:
# dtype('float64')

# %%
#지방함유율값의 대체 (LF to Low Fat , reg to Regular , low fat to Low Fat)
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace({'LF': 'Low Fat', 'reg': 'Regular', 'low fat': 'Low Fat'})

# %%
#create a new column, Year = 2024 - outlet established year
df['Outlet_Age'] = 2024 - df['Outlet_Establishment_Year']

# %%
# item identifier, outlet identifier, item fat content, outlet establishment year, and item type 필요없는 열을 삭제
df.drop(['Item_Identifier', 'Outlet_Identifier', 'Item_Fat_Content', 'Outlet_Establishment_Year', 'Item_Type'], axis=1, inplace=True)

# %%
# 범주형 변수 인코딩
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Outlet_Size'] = le.fit_transform(df['Outlet_Size'])
df['Outlet_Location_Type'] = le.fit_transform(df['Outlet_Location_Type'])
df['Outlet_Type'] = le.fit_transform(df['Outlet_Type'])

# %%
# 독립변수, 종속변수 분리
x = df.drop('Item_Outlet_Sales', axis=1)
y = df['Item_Outlet_Sales']

# %%
#훈련 데이터와 테스트 데이터로 나눔
# 훈련 데이터와 테스트 데이터로 나눔
from sklearn.model_selection import train_test_split
x_train, x_test, y_train ,y_test = train_test_split(x,y,test_size=.2, random_state=42)

# %%
# 회귀분석 모델
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# 잔차 그래프
y_pred = model.predict(x_test)
residuals = y_test - y_pred
plt.scatter(y_pred, residuals)
plt.axhline(y=0, color='r', linestyle='--')
#지금 현재 그래프는 오류가 많이 난다는 그래프 > log를 써서 전환 시킨다 !

# %%
#로그인 변환 후 회귀와 잔차 그래프
model2 = LinearRegression()
model2.fit(np.log1p(x_train), np.log1p(y_train))
# Out:
# LinearRegression()
